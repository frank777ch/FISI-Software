# %% [markdown]
# # Clase 2: ejercicios prácticos resueltos

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

plt.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# ## Parámetros y extracción de datos

# %%
ESTIMACIONES_URL_S3 = "estimaciones_agricolas.zip"
ESTIMACIONES_PATH = "estimaciones-agricolas.csv"

# %%
converters = {
    "id_provincia": lambda x: str(x).zfill(2),
    "id_departamento": lambda x: str(x).zfill(3),
}

estimaciones = pd.read_csv(ESTIMACIONES_URL_S3, encoding="utf8", converters=converters)
#estimaciones.to_csv(ESTIMACIONES_PATH, encoding="utf8", index=False)
#estimaciones = pd.read_csv(ESTIMACIONES_PATH, converters=converters)

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# Explorar descriptivamente el dataset de estimaciones agrícolas (https://datos.gob.ar/dataset/agroindustria-agricultura---estimaciones-agricolas) usando los elementos aprendidos en la clase 2, respondiendo las siguientes preguntas o mostrando:
#
# * ¿Cuál es la producción total en toneladas estimada de todos los cultivos en la Argentina, cada año?
# * ¿Cómo se distribuye el rendimiento (kg por hectárea) estimado promedio del cultivo de soja entre los departamentos que la siembran? ¿Qué tipo de distribución probabilística tiene? ¿Cuál es (y en qué departamento está) el rendimiento mínimo, mediano y máximo? ¿Cuál es el rendimiento promedio? ¿Hay valores potencialmente anómalos?
# * Generá una tabla donde cada cultivo sea una columna, cada fila un año (una campaña) y los valores sean la producción total.

# %%
estimaciones.head()
# Out:
#   id_provincia     provincia id_departamento            departamento
# 0           06  BUENOS AIRES             854              25 DE MAYO  \
# 1           06  BUENOS AIRES             854              25 DE MAYO
# 2           06  BUENOS AIRES             014  ADOLFO GONZALES CHAVES
# 3           06  BUENOS AIRES             014  ADOLFO GONZALES CHAVES
# 4           06  BUENOS AIRES             014  ADOLFO GONZALES CHAVES
#
#    id_cultivo cultivo  id_campaña    campaña  sup_sembrada   sup_cosechada
# 0           1     Ajo           1  1969/1970              3              3  \
# 1           1     Ajo           2  1970/1971              1              1
# 2           1     Ajo           1  1969/1970             15             15
# 3           1     Ajo           2  1970/1971             10             10
# 4           1     Ajo           3  1971/1972              8              8
#
#    produccion   rendimiento
# 0           10         3333
# 1            3         3000
# 2           82         5467
# 3           55         5500
# 4           44         5500

# %%
estimaciones.columns
# Out:
# Index(['id_provincia', 'provincia', 'id_departamento', 'departamento',
#        'id_cultivo', 'cultivo', 'id_campaña', 'campaña', 'sup_sembrada ',
#        'sup_cosechada', 'produccion ', 'rendimiento'],
#       dtype='object')

# %% [markdown]
# Algunos campos tienen espacios al final, es mejor tener nombres de campos sin espacios.

# %%
estimaciones.columns = [col.strip() for col in estimaciones.columns]

# %%
estimaciones
# Out:
#        id_provincia     provincia id_departamento            departamento
# 0                06  BUENOS AIRES             854              25 DE MAYO  \
# 1                06  BUENOS AIRES             854              25 DE MAYO
# 2                06  BUENOS AIRES             014  ADOLFO GONZALES CHAVES
# 3                06  BUENOS AIRES             014  ADOLFO GONZALES CHAVES
# 4                06  BUENOS AIRES             014  ADOLFO GONZALES CHAVES
# ...             ...           ...             ...                     ...
# 136046           90       TUCUMAN             112                 TRANCAS
# 136047           90       TUCUMAN             112                 TRANCAS
# 136048           90       TUCUMAN             112                 TRANCAS
# 136049           90       TUCUMAN             112                 TRANCAS
# 136050           90       TUCUMAN             112                 TRANCAS
#
#         id_cultivo cultivo  id_campaña    campaña  sup_sembrada
# 0                1     Ajo           1  1969/1970             3  \
# 1                1     Ajo           2  1970/1971             1
# 2                1     Ajo           1  1969/1970            15
# 3                1     Ajo           2  1970/1971            10
# 4                1     Ajo           3  1971/1972             8
# ...            ...     ...         ...        ...           ...
# 136046           1     Ajo          25  1993/1994            15
# 136047           1     Ajo          26  1994/1995            15
# 136048           1     Ajo          27  1995/1996            15
# 136049           1     Ajo          28  1996/1997            15
# 136050           1     Ajo          29  1997/1998            15
#
#         sup_cosechada  produccion  rendimiento
# 0                   3          10         3333
# 1                   1           3         3000
# 2                  15          82         5467
# 3                  10          55         5500
# 4                   8          44         5500
# ...               ...         ...          ...
# 136046             13          59         4538
# 136047             13          60         4615
# 136048             15         130         8667
# 136049             13          59         4538
# 136050             13          58         4462
#
# [136051 rows x 12 columns]

# %% [markdown]
# ### Producción total anual

# %%
estimaciones[["campania_inicio","campania_fin"]] = estimaciones.campaña.str.split("/", n=1,expand=True)

# %%
estimaciones["campania_inicio"] = estimaciones["campania_inicio"].astype(int)
estimaciones["campania_fin"] = estimaciones["campania_fin"].astype(int)

# %%
# pasamos los valores a millones
estimaciones["produccion"] = estimaciones.produccion.astype(float) / 1000000

# %%
produccion_anual = estimaciones.pivot_table(
    index="campania_fin",
    values="produccion",
    aggfunc="sum"
)

# %%
produccion_anual.tail()
# Out:
#               produccion
# campania_fin
# 2015          124.498769
# 2016          126.571125
# 2017          246.923268
# 2018          116.768681
# 2019           30.468652

# %%
produccion_anual.plot(
    figsize=(17, 8),
    title="Producción agrícola total anual (tn)"
)
# Out:
# <Axes: title={'center': 'Producción agrícola total anual (tn)'}, xlabel='campania_fin'>

# %% [markdown]
# ¿Está bien ese pico en la campaña 2016/2017? Hay que buscar algún control. https://www.invenomica.com.ar/desempeno-de-la-cosecha-agricola-argentina-2017-2018/ Parece que los datos de 2016/2017 están duplicados! Busquemos cuál es el error en el dataset.

# %%
estimaciones[estimaciones.campaña == "2016/2017"].produccion.sum()
# Out:
# 141.203713

# %% [markdown]
# En realidad los datos de la campaña 2016/2017 parecen estar bien... el problema se da cuando sumamos por el el año de fin de campaña y 2017 aparece duplicado. Tal vez haya un error en los rótulos de las campañas.

# %%
estimaciones[["campaña", "campania_fin"]][
    estimaciones.campania_fin > 2000
].drop_duplicates().sort_values("campania_fin")
# Out:
#        campaña  campania_fin
# 643  2000/2001          2001
# 690  2001/2002          2002
# 691  2002/2003          2003
# 692  2003/2004          2004
# 693  2004/2005          2005
# 694  2005/2006          2006
# 695  2006/2007          2007
# 696  2007/2008          2008
# 697  2008/2009          2009
# 698  2009/2010          2010
# 700  2011/2012          2012
# 701  2012/2013          2013
# 702  2013/2014          2014
# 703  2014/2015          2015
# 704  2015/2016          2016
# 699  2010/2017          2017
# 705  2016/2017          2017
# 706  2017/2018          2018
# 707  2018/2019          2019

# %% [markdown]
# Parece que la campaña 2010/2011 está incorrectamente rotulada como 2010/2017. Antes de seguir adelante, hay que hacer esa corrección.

# %%
estimaciones["campaña"] = estimaciones.campaña.str.replace("2010/2017", "2010/2011")

estimaciones[["campania_inicio","campania_fin"]] = estimaciones.campaña.str.split("/", n=1,expand=True)
estimaciones["campania_inicio"] = estimaciones["campania_inicio"].astype(int)
estimaciones["campania_fin"] = estimaciones["campania_fin"].astype(int)

# %%
produccion_anual = estimaciones.pivot_table(
    index="campania_fin",
    values="produccion",
    aggfunc="sum"
)

# %%
produccion_anual.plot(
    figsize=(17, 8),
    title="Producción agrícola total anual (tn)"
)
# Out:
# <Axes: title={'center': 'Producción agrícola total anual (tn)'}, xlabel='campania_fin'>

# %%
produccion_anual.tail()
# Out:
#               produccion
# campania_fin
# 2015          124.498769
# 2016          126.571125
# 2017          141.203713
# 2018          116.768681
# 2019           30.468652

# %% [markdown]
# La camapaña 2018/2019 está incompleta (el dataset fue actualizado en septiembre de 2019 por última vez) así que también debemos excluirla.

# %%
estimaciones = estimaciones[estimaciones.campaña != "2018/2019"]

# %% [markdown]
# ##  Rendimiento promedio de la soja por departamento

# %%
estimaciones.cultivo.unique()
# Out:
# array(['Ajo', 'Alpiste', 'Avena', 'Cártamo', 'Cebada cervecera',
#        'Cebada forrajera', 'Cebada total', 'Cebolla total', 'Centeno',
#        'Colza', 'Girasol', 'Limón', 'Lino', 'Maíz', 'Mandarina', 'Maní',
#        'Mijo', 'Naranja', 'Papa total', 'Pomelo', 'Poroto seco',
#        'Soja total', 'Sorgo', 'Trigo candeal', 'Trigo total', 'Algodón',
#        'Jojoba', 'Arroz', 'Caña de azúcar', 'Banana', 'Té', 'Tung',
#        'Yerba mate'], dtype=object)

# %% [markdown]
# Ya que nos piden hacer una comparación de rendimientos de la soja entre departamentos, nos conviene realizar los filtros al principio y quedarnos con la muestra que nos interesa en una sola variable.

# %%
estimaciones_soja = estimaciones[
    (estimaciones.cultivo == "Soja total") &
    (estimaciones.campaña == "2017/2018")
]

# %%
len(estimaciones_soja.departamento.unique())
# Out:
# 234

# %% [markdown]
# Hay 234 departamentos que producen Soja, y sobre los cuales hay que hacer el análisis.

# %%
estimaciones_soja.rendimiento.hist(figsize=(17, 8), bins=15);

# %% [markdown]
# Los valores que se separan mucho del histograma, a primera vista podrían sospecharse como anómalos (ie. departamentos con rendimientos superiores a los 4000 kg. por hectárea deberían analizarse más profundamente).

# %%
estimaciones_soja.rendimiento.describe()
# Out:
# count     264.000000
# mean     2233.602273
# std       660.090901
# min       500.000000
# 25%      1811.250000
# 50%      2326.000000
# 75%      2679.000000
# max      5100.000000
# Name: rendimiento, dtype: float64

# %%
estimaciones_soja[estimaciones_soja.rendimiento == estimaciones_soja.rendimiento.max()]
# Out:
#        id_provincia            provincia id_departamento departamento
# 129988           86  SANTIAGO DEL ESTERO             182    SARMIENTO  \
#
#         id_cultivo     cultivo  id_campaña    campaña  sup_sembrada
# 129988          25  Soja total          49  2017/2018           500  \
#
#         sup_cosechada  produccion  rendimiento  campania_inicio  campania_fin
# 129988            500     0.00255         5100             2017          2018

# %%
estimaciones_soja = estimaciones_soja.copy()
estimaciones_soja['diferencia_mediana'] = np.abs(estimaciones_soja.rendimiento - estimaciones_soja['rendimiento'].median())

# %%
estimaciones_soja[estimaciones_soja['rendimiento'] == estimaciones_soja['rendimiento'].median()]
# Out:
# Empty DataFrame
# Columns: [id_provincia, provincia, id_departamento, departamento, id_cultivo, cultivo, id_campaña, campaña, sup_sembrada, sup_cosechada, produccion, rendimiento, campania_inicio, campania_fin, diferencia_mediana]
# Index: []

# %%
estimaciones_soja[estimaciones_soja['diferencia_mediana'] == estimaciones_soja['diferencia_mediana'].min()]
# Out:
#        id_provincia     provincia id_departamento departamento  id_cultivo
# 33503            06  BUENOS AIRES             609      PEHUAJO          25  \
# 108891           66         SALTA             042     CHICOANA          25
# 123308           82      SANTA FE             021  CASTELLANOS          25
#
#            cultivo  id_campaña    campaña  sup_sembrada  sup_cosechada
# 33503   Soja total          49  2017/2018        138790         132090  \
# 108891  Soja total          49  2017/2018           220            220
# 123308  Soja total          49  2017/2018        251000         239000
#
#         produccion  rendimiento  campania_inicio  campania_fin
# 33503     0.303828         2300             2017          2018  \
# 108891    0.000506         2300             2017          2018
# 123308    0.562100         2352             2017          2018
#
#         diferencia_mediana
# 33503                 26.0
# 108891                26.0
# 123308                26.0

# %%
estimaciones_soja[estimaciones_soja.rendimiento == estimaciones_soja.rendimiento.min()]
# Out:
#       id_provincia provincia id_departamento departamento  id_cultivo
# 90520           42  LA PAMPA             070    GUATRACHE          25  \
#
#           cultivo  id_campaña    campaña  sup_sembrada  sup_cosechada
# 90520  Soja total          49  2017/2018          1500           1000  \
#
#        produccion  rendimiento  campania_inicio  campania_fin
# 90520      0.0005          500             2017          2018  \
#
#        diferencia_mediana
# 90520              1826.0

# %% [markdown]
# ### Tabla de evolución de producción por cultivo

# %%
produccion_cultivo_evolucion = estimaciones.pivot_table(
    index="campaña",
    columns="cultivo",
    values="produccion",
    aggfunc="sum"
)
produccion_cultivo_evolucion
# Out:
# cultivo         Ajo   Algodón   Alpiste     Arroz     Avena    Banana
# campaña
# 1969/1970  0.049110  0.458200  0.107000  0.407000  0.425000  0.223440  \
# 1970/1971  0.049214  0.285000  0.039300  0.288000  0.359960  0.224800
# 1971/1972  0.050746  0.292200  0.026200  0.294000  0.475000  0.312700
# 1972/1973  0.054545  0.424000  0.035000  0.260000  0.566000  0.352160
# 1973/1974  0.066821  0.418400  0.034000  0.316000  0.561000  0.399400
# 1974/1975  0.067621  0.541000  0.025400  0.351000  0.327000  0.374300
# 1975/1976  0.068525  0.445000  0.032800  0.309000  0.432900  0.277500
# 1976/1977  0.072925  0.522000  0.039000  0.320000  0.530000  0.220000
# 1977/1978  0.078900  0.786200  0.060000  0.310000  0.570000  0.128700
# 1978/1979  0.080920  0.572500  0.051000  0.312000  0.676000  0.144000
# 1979/1980  0.094932  0.485400  0.042000  0.266000  0.522000  0.146200
# 1980/1981  0.068939  0.265300  0.035200  0.286300  0.433000  0.077000
# 1981/1982  0.037680  0.491000  0.032300  0.437200  0.338970  0.088700
# 1982/1983  0.048083  0.373300  0.063000  0.337100  0.636970  0.126100
# 1978/1979  ...    1.693285  0.134000     0.235000    3.700000  6.200000
# 1979/1980  ...    1.567615  0.164000     0.146000    3.500000  2.960000
# 1980/1981  ...    2.246470  0.150000     0.224000    3.770000  7.550000
# 1981/1982  ...    1.816780  0.147600     0.254000    4.150000  7.999925
# 1982/1983  ...    2.013080  0.147000     0.216500    4.000000  8.099900
# 1983/1984  ...    2.105580  0.145000     0.191200    7.000000  6.899865
# 1984/1985  ...    2.243180  0.173700     0.198300    6.500000  6.199700
# 1985/1986  ...    2.057540  0.177900     0.210500    7.100000  3.999875
# 1986/1987  ...    2.103300  0.174193     0.135255    6.666400  2.996630
# 1987/1988  ...    2.859030  0.176100     0.172300    9.900000  3.200000
# 1988/1989  ...    2.064575  0.154700     0.124800    6.500000  1.500000
# 1989/1990  ...    1.598121  0.166580     0.207845   10.700000  2.050000
# 1990/1991  ...    1.749842  0.203900     0.241578   10.861200  2.252400
# 1991/1992  ...    1.628460  0.191900     0.210410   11.308100  2.767000
# 1992/1993  ...    2.104907  0.196540     0.164440   11.043400  2.859700
# 1993/1994  ...    2.422577  0.228671     0.195626   11.719900  2.148000
# 1994/1995  ...    2.427742  0.195918     0.236285   12.133000  1.649482
# 1995/1996  ...    2.274945  0.166784     0.218313   12.448200  2.131720
# 1996/1997  ...    3.011328  0.232766     0.268279   11.004890  2.499000
# 1997/1998  ...    3.406761       NaN     0.303245   18.732172  3.762335
# 1998/1999  ...         NaN       NaN     0.340214   20.000000  3.221750
# 1999/2000  ...         NaN       NaN     0.297157   20.135800  3.344493
# 2000/2001  ...         NaN       NaN     0.262985   27.266253  2.908775
# 2001/2002  ...         NaN       NaN     0.278100   29.991616  2.804725
# 2002/2003  ...         NaN       NaN     0.215552   34.818550  2.663550
# 2003/2004  ...         NaN       NaN     0.151278   31.576752  2.121733
# 2004/2005  ...         NaN       NaN     0.169257   38.303289  2.894250
# 2005/2006  ...         NaN       NaN     0.322775   40.537368  2.327865
# 2006/2007  ...         NaN       NaN     0.327689   47.482787  2.794967
# 2007/2008  ...         NaN       NaN     0.336779   46.238890  2.940788
# 2008/2009  ...         NaN       NaN     0.312998   30.989474  1.475870
# 2009/2010  ...         NaN       NaN     0.338120   54.247538  3.637427
# 2010/2011  ...         NaN       NaN     0.332782   48.880986  4.458442
# 2011/2012  ...         NaN       NaN     0.361153   40.100197  4.252310
# 2012/2013  ...         NaN       NaN     0.095741   49.353642  3.635837
# 2013/2014  ...         NaN       NaN     0.429832   53.397720  3.466410
# 2014/2015  ...         NaN       NaN     0.604817   61.398276  3.098148
# 2015/2016  ...         NaN       NaN     0.366588   58.799259  3.029330
# 2016/2017  ...         NaN       NaN     0.413605   54.972546  2.526931
# 2017/2018  ...         NaN       NaN     0.473389   37.787927  1.563445
#
# cultivo    Trigo candeal  Trigo total      Tung        Té  Yerba mate
# campaña
# 1969/1970            NaN     7.019726  0.148600  0.111000    0.076788
# 1970/1971            NaN     4.919767  0.110000  0.129000    0.090460
# 1971/1972            NaN     5.439840  0.170000  0.131000    0.126714
